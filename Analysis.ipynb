# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_listing = pd.read_csv("data/CRMLSListingMaster.csv", low_memory=False)
data_sold = pd.read_csv("data/CRMLSSoldMaster.csv", low_memory=False)

data_listing.head()
# Out:
#               source_file  file_period   sort_date  OriginalListPrice  \
# 0  CRMLSListing202401.csv       202401  2024-01-01          1399990.0
# 1  CRMLSListing202401.csv       202401  2024-01-01           789900.0
# 2  CRMLSListing202401.csv       202401  2024-01-01          1050000.0
# 3  CRMLSListing202401.csv       202401  2024-01-01          1250000.0
# 4  CRMLSListing202401.csv       202401  2024-01-01          4750000.0
#
#    ListingKey             ListAgentEmail   CloseDate  ClosePrice  \
# 0  1043760653    joe@porchlightsocal.com  2024-03-15   1270000.0
# 1  1053093534      kiva@kivakendrick.com  2024-02-26    800000.0
# 2  1054014526  sarah.pearce@cbrealty.com         NaN         NaN
# 3  1054022382     mricks@mypsrealtor.com  2024-02-26   1199000.0
# 4  1054022420   james@larealproperty.com         NaN         NaN
#
#   ListAgentFirstName ListAgentLastName  ...  MainLevelBedrooms  \
# 0             Joseph            Vahedi  ...                2.0
# ...

# %%
data_sold.shape, data_listing.shape
# Out:
# ((371009, 87), (499306, 87))

# %%
# 查看 data_listing 第 46 列的列名
col_46_name = data_listing.columns[46]
print(f"data_listing 第 46 列的名字是: {col_46_name}")
print(f"它的数据类型被识别为: {data_listing[col_46_name].dtype}")

print("-" * 30)

# 查看 data_sold 第 3, 4, 81 列的列名
problem_cols = [3, 4, 81, 82, 83, 85, 86]
for i in problem_cols:
    col_name = data_sold.columns[i]
    print(f"data_sold 第 {i} 列的名字是: {col_name}")
# Out:
# data_listing 第 46 列的名字是: BuyerAgencyCompensationType
# 它的数据类型被识别为: object
# ------------------------------
# data_sold 第 3 列的名字是: BuyerAgentAOR
# data_sold 第 4 列的名字是: ListAgentAOR
# data_sold 第 81 列的名字是: OriginatingSystemName
# data_sold 第 82 列的名字是: OriginatingSystemSubName
# data_sold 第 83 列的名字是: BuyerAgencyCompensationType
# data_sold 第 85 列的名字是: latfilled
# data_sold 第 86 列的名字是: lonfilled

# %%
# Identify high-missing columns for any loaded dataframe in this notebook
missing_threshold = 0.50

datasets = {}
if 'data_listing' in globals():
    datasets['data_listing'] = data_listing
if 'data_sold' in globals():
    datasets['data_sold'] = data_sold
if 'df' in globals():
    datasets['df'] = df

for name, dataset in datasets.items():
    missing_summary = pd.DataFrame({
        'missing_count': dataset.isna().sum(),
        'missing_ratio': dataset.isna().mean()
    }).sort_values('missing_ratio', ascending=False)

    high_missing_columns = missing_summary[missing_summary['missing_ratio'] >= missing_threshold]

    print(f'High-missing columns in {name} (threshold = {missing_threshold:.0%})')
    display(high_missing_columns)
    print('-' * 60)
