# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_listing = pd.read_csv("data/CRMLSListingMaster.csv", low_memory=False)
data_sold = pd.read_csv("data/CRMLSSoldMaster.csv", low_memory=False)

data_listing.head()
# Out:
#               source_file  file_period   sort_date  OriginalListPrice  \
# 0  CRMLSListing202401.csv       202401  2024-01-01          1399990.0
# 1  CRMLSListing202401.csv       202401  2024-01-01           789900.0
# 2  CRMLSListing202401.csv       202401  2024-01-01          1050000.0
# 3  CRMLSListing202401.csv       202401  2024-01-01          1250000.0
# 4  CRMLSListing202401.csv       202401  2024-01-01          4750000.0
#
#    ListingKey             ListAgentEmail   CloseDate  ClosePrice  \
# 0  1043760653    joe@porchlightsocal.com  2024-03-15   1270000.0
# 1  1053093534      kiva@kivakendrick.com  2024-02-26    800000.0
# 2  1054014526  sarah.pearce@cbrealty.com         NaN         NaN
# 3  1054022382     mricks@mypsrealtor.com  2024-02-26   1199000.0
# 4  1054022420   james@larealproperty.com         NaN         NaN
#
#   ListAgentFirstName ListAgentLastName  ...  MainLevelBedrooms  \
# 0             Joseph            Vahedi  ...                2.0
# 1               Kiva          Kendrick  ...                NaN
# 2              Sarah            Pearce  ...                NaN
# 3            Michael             Ricks  ...                NaN
# 4              James           Maxwell  ...                NaN
#
#    NewConstructionYN GarageSpaces   HighSchoolDistrict  PostalCode  \
# 0                NaN          2.0        Vista Unified       92083
# 1              False          2.0  Los Angeles Unified       90746
# 2              False          NaN                  NaN       92262
# 3              False          2.0                  NaN       92262
# 4              False          2.0                  NaN       90291
#
#              BuyerOfficeName__dup2  AssociationFee LotSizeSquareFeet  \
# 0        eXp Realty of Southern CA           252.0            9897.0
# 1                     R & R Realty             NaN            5070.0
# 2                              NaN             NaN           10019.0
# 3  BHG Desert Lifestyle Properties             NaN           10454.0
# 4                              NaN             NaN            3084.0
#
#   MiddleOrJuniorSchoolDistrict     UnparsedAddress__dup2
# 0                          NaN           123 Flores Lane
# 1                          NaN        19922 Enslow Drive
# 2                          NaN        2030 E Acacia Road
# 3                          NaN  1695 E Buena Vista Drive
# 4                          NaN        2915 S Grand Canal
#
# [5 rows x 87 columns]

# %%
data_sold.shape, data_listing.shape
# Out:
# ((371009, 87), (499306, 87))

# %%
def missing_summary(df, df_name="data"):
    missing_count = df.isna().sum()
    missing_pct = df.isna().mean() * 100

    summary = pd.DataFrame({
        "column": df.columns,
        "missing_count": missing_count.values,
        "missing_pct": missing_pct.values
    }).sort_values("missing_pct", ascending=False)

    high_missing = summary[summary["missing_pct"] > 90]

    print(f"\nMissing value summary for {df_name}:")
    display(summary)

    print(f"\nColumns in {df_name} with >90% missing values:")
    display(high_missing)

    return summary, high_missing

# %%
listing_missing_summary, listing_high_missing = missing_summary(data_listing, "data_listing")
sold_missing_summary, sold_high_missing = missing_summary(data_sold, "data_sold")
# Out:
# Missing value summary for data_listing:
#                           column  missing_count  missing_pct
# 63                  BusinessType         499306        100.0
# 67                 CoveredSpaces         499306        100.0
# 85  MiddleOrJuniorSchoolDistrict         499306        100.0
# 53                       TaxYear         499306        100.0
# 31               TaxAnnualAmount         499306        100.0
# ..                           ...            ...          ...
# 33            PropertyType__dup2              0          0.0
# 29             ListingKeyNumeric              0          0.0
# 34                     MlsStatus              0          0.0
# 65               ListPrice__dup2              0          0.0
# 61           ListingContractDate              0          0.0
#
# [87 rows x 3 columns]
# Columns in data_listing with >90% missing values:
#                           column  missing_count  missing_pct
# 63                  BusinessType         499306   100.000000
# 67                 CoveredSpaces         499306   100.000000
# 85  MiddleOrJuniorSchoolDistrict         499306   100.000000
# 53                       TaxYear         499306   100.000000
# 31               TaxAnnualAmount         499306   100.000000
# 28        AboveGradeFinishedArea         499306   100.000000
# 26               FireplacesTotal         499306   100.000000
# 58      ElementarySchoolDistrict         499306   100.000000
# 62        BelowGradeFinishedArea         496530    99.444028
# 59         CoBuyerAgentFirstName         485774    97.289838
# 39                   BuilderName         476018    95.335926
# 75             LotSizeDimensions         473139    94.759326
# 54             BuildingAreaTotal         455168    91.160130
# Missing value summary for data_sold:
#                           column  missing_count  missing_pct
# 63                  BusinessType         371009        100.0
# 65                 CoveredSpaces         371009        100.0
# 80  MiddleOrJuniorSchoolDistrict         371009        100.0
# 54                       TaxYear         371009        100.0
# 33               FireplacesTotal         371009        100.0
# ..                           ...            ...          ...
# 36             ListingKeyNumeric              0          0.0
# 24                ListOfficeName              0          0.0
# 23                  DaysOnMarket              0          0.0
# 39                CountyOrParish              0          0.0
# 64               StateOrProvince              0          0.0
#
# [87 rows x 3 columns]
# Columns in data_sold with >90% missing values:
#                           column  missing_count  missing_pct
# 63                  BusinessType         371009   100.000000
# 65                 CoveredSpaces         371009   100.000000
# 80  MiddleOrJuniorSchoolDistrict         371009   100.000000
# 54                       TaxYear         371009   100.000000
# 33               FireplacesTotal         371009   100.000000
# 38               TaxAnnualAmount         371009   100.000000
# 35        AboveGradeFinishedArea         371009   100.000000
# 58      ElementarySchoolDistrict         371009   100.000000
# 7                   WaterfrontYN         370783    99.939085
# 62        BelowGradeFinishedArea         368897    99.430742
# 8                     BasementYN         363720    98.035358
# 81         OriginatingSystemName         358351    96.588223
# 82      OriginatingSystemSubName         358351    96.588223
# 71             LotSizeDimensions         352983    95.141358
# 44                   BuilderName         352902    95.119525
# 55             BuildingAreaTotal         345161    93.033053
# 59         CoBuyerAgentFirstName         337490    90.965448

# %%
drop_listing = [
    "BusinessType",
    "CoveredSpaces",
    "MiddleOrJuniorSchoolDistrict",
    "TaxYear",
    "TaxAnnualAmount",
    "AboveGradeFinishedArea",
    "FireplacesTotal",
    "ElementarySchoolDistrict",
    "BelowGradeFinishedArea",
    "CoBuyerAgentFirstName",
    "BuilderName",
    "LotSizeDimensions"
]

drop_sold = [
    "BusinessType",
    "CoveredSpaces",
    "MiddleOrJuniorSchoolDistrict",
    "TaxYear",
    "FireplacesTotal",
    "TaxAnnualAmount",
    "AboveGradeFinishedArea",
    "ElementarySchoolDistrict",
    "WaterfrontYN",
    "BelowGradeFinishedArea",
    "BasementYN",
    "OriginatingSystemName",
    "OriginatingSystemSubName",
    "LotSizeDimensions",
    "BuilderName",
    "CoBuyerAgentFirstName"
]

data_listing_clean = data_listing.drop(columns=drop_listing, errors="ignore")
data_sold_clean = data_sold.drop(columns=drop_sold, errors="ignore")

# %%
data_listing_clean.head()
# Out:
#               source_file  file_period   sort_date  OriginalListPrice  \
# 0  CRMLSListing202401.csv       202401  2024-01-01          1399990.0
# 1  CRMLSListing202401.csv       202401  2024-01-01           789900.0
# 2  CRMLSListing202401.csv       202401  2024-01-01          1050000.0
# 3  CRMLSListing202401.csv       202401  2024-01-01          1250000.0
# 4  CRMLSListing202401.csv       202401  2024-01-01          4750000.0
#
#    ListingKey             ListAgentEmail   CloseDate  ClosePrice  \
# 0  1043760653    joe@porchlightsocal.com  2024-03-15   1270000.0
# 1  1053093534      kiva@kivakendrick.com  2024-02-26    800000.0
# 2  1054014526  sarah.pearce@cbrealty.com         NaN         NaN
# 3  1054022382     mricks@mypsrealtor.com  2024-02-26   1199000.0
# 4  1054022420   james@larealproperty.com         NaN         NaN
#
#   ListAgentFirstName ListAgentLastName  ...  LotSizeArea  MainLevelBedrooms  \
# 0             Joseph            Vahedi  ...       9897.0                2.0
# 1               Kiva          Kendrick  ...       5070.0                NaN
# 2              Sarah            Pearce  ...      10019.0                NaN
# 3            Michael             Ricks  ...      10454.0                NaN
# 4              James           Maxwell  ...       3084.0                NaN
#
#   NewConstructionYN GarageSpaces   HighSchoolDistrict  PostalCode  \
# 0               NaN          2.0        Vista Unified       92083
# 1             False          2.0  Los Angeles Unified       90746
# 2             False          NaN                  NaN       92262
# 3             False          2.0                  NaN       92262
# 4             False          2.0                  NaN       90291
#
#              BuyerOfficeName__dup2 AssociationFee LotSizeSquareFeet  \
# 0        eXp Realty of Southern CA          252.0            9897.0
# 1                     R & R Realty            NaN            5070.0
# 2                              NaN            NaN           10019.0
# 3  BHG Desert Lifestyle Properties            NaN           10454.0
# 4                              NaN            NaN            3084.0
#
#       UnparsedAddress__dup2
# 0           123 Flores Lane
# 1        19922 Enslow Drive
# 2        2030 E Acacia Road
# 3  1695 E Buena Vista Drive
# 4        2915 S Grand Canal
#
# [5 rows x 75 columns]

# %%
data_sold_clean.head()
# Out:
#            source_file  file_period   sort_date        BuyerAgentAOR  \
# 0  CRMLSSold202401.csv       202401  2024-01-01         OrangeCounty
# 1  CRMLSSold202401.csv       202401  2024-01-01  NorthSanDiegoCounty
# 2  CRMLSSold202401.csv       202401  2024-01-01            Southland
# 3  CRMLSSold202401.csv       202401  2024-01-01             SanDiego
# 4  CRMLSSold202401.csv       202401  2024-01-01          PacificWest
#
#           ListAgentAOR       Flooring ViewYN PoolPrivateYN  OriginalListPrice  \
# 0         OrangeCounty    Carpet,Tile  False         False           854990.0
# 1  NorthSanDiegoCounty  Laminate,Tile  False         False           399000.0
# 2            Southland    Carpet,Tile  False         False           549999.0
# 3             SanDiego            NaN   True         False          1750000.0
# 4          PacificWest  Laminate,Tile  False         False           535000.0
#
#    ListingKey  ... NewConstructionYN GarageSpaces     HighSchoolDistrict  \
# 0  1040790377  ...              True          2.0     Montebello Unified
# 1  1044747152  ...             False          2.0  Antelope Valley Union
# 2  1045213113  ...             False          3.0               Palmdale
# 3  1045523677  ...             False          2.0                    NaN
# 4  1046369026  ...             False          2.0         Rialto Unified
#
#   PostalCode AssociationFee  LotSizeSquareFeet  BuyerAgencyCompensationType  \
# 0      90640          236.0                NaN                          NaN
# 1      93536            0.0             6882.0                          NaN
# 2      93552            0.0             7293.0                          NaN
# 3      92054          695.0            13567.0                          NaN
# 4      92376            0.0             7700.0                          NaN
#
#   BuyerAgencyCompensation latfilled  lonfilled
# 0                     NaN       NaN        NaN
# 1                     NaN       NaN        NaN
# 2                     NaN       NaN        NaN
# 3                     NaN       NaN        NaN
# 4                     NaN       NaN        NaN
#
# [5 rows x 71 columns]
